# %%
import pandas as pd
import requests
import json

# 2. Fetch data from API
response = requests.get('http://127.0.0.1:8001/cleaned_songs')
df_api = pd.DataFrame(response.json())

df_api.head()
# Out:
#                  track_id          track_name           track_artist  \
# 0  2plbrEY59IikOBgBGLjaoe    Die With A Smile  Lady Gaga, Bruno Mars
# 1  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER          Billie Eilish
# 2  7ne4VBA60CxGM75vw0EYad      That’s So True          Gracie Abrams
# 3  1d7Ptw3qYcfpdLNL5REhtJ               Taste      Sabrina Carpenter
# 4  5vNRhkKd0yEAg8suGBpjeY                APT.       ROSÉ, Bruno Mars
#
#             track_album_name track_album_release_date playlist_genre  \
# 0           Die With A Smile               2024-08-16            pop
# 1       HIT ME HARD AND SOFT               2024-05-17            pop
# 2  The Secret of Us (Deluxe)               2024-10-18            pop
# 3             Short n' Sweet               2024-08-23            pop
# 4                       APT.               2024-10-18            pop
#
#   playlist_subgenre  energy  danceability    tempo  ...  acousticness  \
# ...
